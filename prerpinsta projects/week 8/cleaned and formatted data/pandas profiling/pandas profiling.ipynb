# %%
import pandas as pd

# %%
df = pd.read_csv('dailyActivity.csv')
df1 = pd.read_csv('HourlyActivity.csv')
df2 = pd.read_csv('MinutelyActivity.csv')

# %%
df
# Out:
#                Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1.503960e+09   12-04-2016       13162           8.50             8.50
# 1    1.503960e+09   13-04-2016       10735           6.97             6.97
# 2    1.503960e+09   14-04-2016       10460           6.74             6.74
# 3    1.503960e+09   15-04-2016        9762           6.28             6.28
# 4    1.503960e+09   16-04-2016       12669           8.16             8.16
# ..            ...          ...         ...            ...              ...
# 935  8.877689e+09   08-05-2016       10686           8.11             8.11
# 936  8.877689e+09   09-05-2016       20226          18.25            18.25
# 937  8.877689e+09   10-05-2016       10733           8.15             8.15
# 938  8.877689e+09   11-05-2016       21420          19.56            19.56
# 939  8.877689e+09   12-05-2016        8064           6.12             6.12
#
# ...

# %%
df1
# Out:
#                Id        Activity Hour  Calories  TotalIntensity  \
# 0      1503960366  12-04-2016 00:00:00        81              20
# 1      1503960366  12-04-2016 01:00:00        61               8
# 2      1503960366  12-04-2016 02:00:00        59               7
# 3      1503960366  12-04-2016 03:00:00        47               0
# 4      1503960366  12-04-2016 04:00:00        48               0
# ...           ...                  ...       ...             ...
# 22094  8877689391  12-05-2016 10:00:00       126              12
# 22095  8877689391  12-05-2016 11:00:00       192              29
# 22096  8877689391  12-05-2016 12:00:00       321              93
# 22097  8877689391  12-05-2016 13:00:00       101               6
# 22098  8877689391  12-05-2016 14:00:00       113               9
#
#        AverageIntensity  StepTotal
# 0                 0.333        373
# 1                 0.133        160
# 2                 0.117        151
# 3                 0.000          0
# ...

# %%
df2
# Out:
#                  Id      ActivityMinutes  Calories  Intensity  METs  Steps
# 0        1503960366  12-04-2016 12:00:00     0.786          0    10      0
# 1        1503960366  12-04-2016 12:00:00     0.786          0    10      0
# 2        1503960366  12-04-2016 12:00:00     0.786          0    12      0
# 3        1503960366  12-04-2016 12:00:00     0.786          0    12      0
# 4        1503960366  12-04-2016 12:00:00     0.786          0    10      0
# ...             ...                  ...       ...        ...   ...    ...
# 3709690  7086361926  17-04-2016 19:10:00     1.132          0    10      0
# 3709691  7086361926  17-04-2016 19:11:00     1.132          0    10      0
# 3709692  7086361926  17-04-2016 19:12:00     1.132          0    10      0
# 3709693  7086361926  17-04-2016 19:13:00     1.132          0    10      0
# 3709694  7086361926  17-04-2016 19:14:00     1.132          0    10      0
#
# [3709695 rows x 6 columns]

# %%
from ydata_profiling import ProfileReport
from ydata_profiling.utils.cache import cache_file
report = ProfileReport(df,title='DailyActivityReport',explorative=True)
report.to_file('DailyActivityReport.html')
# Out:
# C:\Users\Mikey\anaconda3\Lib\site-packages\numba\core\decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# C:\Users\Mikey\anaconda3\Lib\site-packages\visions\backends\shared\nan_handling.py:50: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @nb.jit
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from ydata_profiling import ProfileReport
from ydata_profiling.utils.cache import cache_file
report = ProfileReport(df1,title='HourlyActivityReport',explorative=True)
report.to_file('HourlyActivityReport.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from ydata_profiling import ProfileReport
from ydata_profiling.utils.cache import cache_file
report = ProfileReport(df2,title='MinutelyActivityReport',explorative=True)
report.to_file('MinutelyActivityReport.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
